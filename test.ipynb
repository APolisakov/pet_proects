# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/user/Project/project/GitHub/parsing/results_models_rm.csv')

# %%
df
# Out:
#                                    model            cv       train  \
# 0    RandomForestRegressor_0.999MAEstart -9.921118e+02      442.04
# 1    RandomForestRegressor_0.999MSEstart -4.248549e+06   964914.64
# 2   RandomForestRegressor_0.999MAPEstart -1.531000e-01        0.07
# 3   RandomForestRegressor_0.999RMSEstart  8.955000e-01        0.98
# 4        CatBoostRegressor_0.999MAEstart -1.259825e+03      680.81
# 5        CatBoostRegressor_0.999MSEstart -4.767230e+06  1292051.90
# 6       CatBoostRegressor_0.999MAPEstart -2.202000e-01        0.14
# 7       CatBoostRegressor_0.999RMSEstart  8.821000e-01        0.97
# 8            LGBMRegressor_0.999MAEstart -1.035845e+03      306.02
# 9            LGBMRegressor_0.999MSEstart -3.778971e+06   543816.32
# 10          LGBMRegressor_0.999MAPEstart -1.616000e-01        0.06
# 11          LGBMRegressor_0.999RMSEstart  9.071000e-01        0.99
# 12   DecisionTreeRegressor_0.999MAEstart -1.283829e+03      604.16
# ...
